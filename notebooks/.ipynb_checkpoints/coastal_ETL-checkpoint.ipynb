# %%
import os
import shutil
import glob
from osgeo import gdal
import geopandas as gpd
from shapely.geometry import box
import numpy as np
import rasterio
from rasterio.features import geometry_mask
import sys
from gdal_retile import main as gdal_retile_main
import pandas as pd

# %%
# Project params

project_path = r"C:\Users\owyn\Documents\SURV509\coastal classification"
input_dir = os.path.join(project_path, "inputs")

# %% [markdown]
# ### Merging geojpeg files in each region

# %%
# Define paths
aerial_imagery_dir = os.path.join(input_dir, '0.3m Aerial Imagery')
urban_shapefile = os.path.join(input_dir, 'urban', 'urban-areas.shp')
coastline_shapefile = os.path.join(input_dir, 'linz', 'lds-nz-coastlines-topo-150k-JPEG-SHP', 'nz-coastlines-topo-150k.shp')

# Load shapefiles
urban_areas = gpd.read_file(urban_shapefile)
coastlines = gpd.read_file(coastline_shapefile)

output_coastline_shapefile = os.path.join(input_dir, 'urban', 'intersecting_coastline.shp')
# Apply a 100 meter buffer to the urban areas
buffered_urban_areas = urban_areas.buffer(100)

# Find the intersection of the buffered urban areas and the coastline
intersecting_coastlines = gpd.overlay(coastlines, gpd.GeoDataFrame(geometry=buffered_urban_areas), how='intersection')

# Save the intersecting coastline segments to a new shapefile
intersecting_coastlines.to_file(output_coastline_shapefile)

print(f"Intersecting coastline shapefile created at {output_coastline_shapefile}")
# Out:
# Intersecting coastline shapefile created at C:\Users\owyn\Documents\SURV509\coastal classification\inputs\urban\intersecting_coastline.shp

# %%
# Function to resample GeoJPEG to 0.3m resolution
def resample_to_30cm(file_path):
    output_file_path = file_path.replace('.jpg', '_resampled.jpg')
    gdal.Warp(output_file_path, file_path, xRes=0.3, yRes=0.3, resampleAlg='bilinear')
    return output_file_path

# Function to check intersection
def check_intersection(aerial_dir):
    valid_files = []
    for root, _, files in os.walk(aerial_dir):
        for file in files:
            if file.endswith('.jpg') or file.endswith('.jpeg'):
                file_path = os.path.join(root, file)
                with rasterio.open(file_path) as src:
                    transform = src.transform
                    cell_width, cell_height = transform[0], -transform[4]

                    # Check if cell size is approximately 0.3m
                    if not (0.295 <= cell_width <= 0.305 and 0.295 <= cell_height <= 0.305):
                        file_path = resample_to_30cm(file_path)

                    with rasterio.open(file_path) as resampled_src:
                        bounds = resampled_src.bounds
                        geom = box(*bounds)
                        intersects_urban = urban_areas.intersects(geom).any()
                        intersects_coastline = coastlines.intersects(geom).any()
                    
                        if intersects_urban or intersects_coastline:
                            valid_files.append(file_path)
    return valid_files

def retile_images(geo_jpeg_paths, output_directory):
    """
    Retile the given list of GeoJPEG paths and save the output to the specified directory.
    
    Args:
        geo_jpeg_paths (list of str): List of paths to GeoJPEG files.
        output_directory (str): Directory where the retiled images will be saved.
    """
    # Create the output directory if it doesn't exist
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    # Prepare the arguments for gdal_retile.py
    args = [
        'gdal_retile.py', 
        '-targetDir', output_directory, 
        '-ps', '224', '224',
        '-r', 'bilinear'
    ] + geo_jpeg_paths

    # Run the gdal_retile function
    sys.argv = args
    gdal_retile_main()

    print(f"Retiled images saved to {output_directory}")

def filter_tifs_by_coastline(retiled_dir, coastline_shapefile):
    """
    Filter TIFF files in the retiled directory, keeping only those that intersect with the coastline.
    
    Args:
        retiled_dir (str): Directory containing the retiled TIFF files.
        coastline_shapefile (str): Path to the coastline shapefile.
    """
    # Load coastline shapefile
    coastlines = gpd.read_file(coastline_shapefile)

    # List of TIFF files to keep
    valid_tifs = []

    # Iterate over TIFF files in the retiled directory
    for tif_file in glob.glob(os.path.join(retiled_dir, '*.tif')):
        with rasterio.open(tif_file) as src:
            bounds = src.bounds
            geom = box(*bounds)
            intersects_coastline = coastlines.intersects(geom).any()
            
            if intersects_coastline:
                valid_tifs.append(tif_file)
    
    # Move invalid TIFF files to a subfolder 'invalid'
    invalid_dir = os.path.join(retiled_dir, 'invalid')
    if not os.path.exists(invalid_dir):
        os.makedirs(invalid_dir)
    
    for tif_file in glob.glob(os.path.join(retiled_dir, '*.tif')):
        if tif_file not in valid_tifs:
            shutil.move(tif_file, invalid_dir)

    print(f"Filtered TIFF files saved in {retiled_dir}. Invalid files moved to {invalid_dir}")

def filter_tifs_by_dimensions(retiled_dir, target_width=224, target_height=224):
    """
    Filter TIFF files in the retiled directory, moving those that do not match the target dimensions to an 'invalid' folder.
    
    Args:
        retiled_dir (str): Directory containing the retiled TIFF files.
        target_width (int): Target width of the TIFF files.
        target_height (int): Target height of the TIFF files.
    """
    # Directory for invalid TIFF files
    invalid_dir = os.path.join(retiled_dir, 'invalid')
    if not os.path.exists(invalid_dir):
        os.makedirs(invalid_dir)
    
    # Iterate over TIFF files in the retiled directory
    for tif_file in glob.glob(os.path.join(retiled_dir, '*.tif')):
        with rasterio.open(tif_file) as src:
            width, height = src.width, src.height
            
        if width != target_width or height != target_height:
            shutil.move(tif_file, invalid_dir)
            print(f"Moved {tif_file} to {invalid_dir} due to incorrect dimensions ({width}x{height})")
    
    print(f"Checked TIFF files for dimensions in {retiled_dir}. Invalid files moved to {invalid_dir}")

# %%
# Main processing loop

# Dictionary to store valid JPEG paths
valid_jpegs = {}

aerial_imagery_base_dir = os.path.join(input_dir, '0.3m Aerial Imagery')

for region_name in os.listdir(aerial_imagery_base_dir):
    region_dir = os.path.join(aerial_imagery_base_dir, region_name)
    if os.path.isdir(region_dir):
        retile_output_dir = os.path.join(region_dir, 'retiled')
        
        if not os.path.exists(retile_output_dir) or not os.listdir(retile_output_dir):
            valid_jpegs[region_name] = check_intersection(region_dir)
            print(f"Intersecting tiles found for {region_name}")
            
            # Retile the valid files
            retile_images(valid_jpegs[region_name], retile_output_dir)
        
        # Filter TIFF files by intersection with coastline (urban coastline)
        filter_tifs_by_coastline(retile_output_dir, output_coastline_shapefile)
        filter_tifs_by_dimensions(retile_output_dir, target_width=224, target_height=224)

print("Processing complete.")
# Out:
# Filtered TIFF files saved in C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\christchurch\retiled. Invalid files moved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\christchurch\retiled\invalid
# Checked TIFF files for dimensions in C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\christchurch\retiled. Invalid files moved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\christchurch\retiled\invalid
# Filtered TIFF files saved in C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\dunedin\retiled. Invalid files moved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\dunedin\retiled\invalid
# Checked TIFF files for dimensions in C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\dunedin\retiled. Invalid files moved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\dunedin\retiled\invalid
# Filtered TIFF files saved in C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\greymouth\retiled. Invalid files moved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\greymouth\retiled\invalid
# Checked TIFF files for dimensions in C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\greymouth\retiled. Invalid files moved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\greymouth\retiled\invalid
# Filtered TIFF files saved in C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\invercargill\retiled. Invalid files moved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\invercargill\retiled\invalid
# Checked TIFF files for dimensions in C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\invercargill\retiled. Invalid files moved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\invercargill\retiled\invalid
# Filtered TIFF files saved in C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\mapua\retiled. Invalid files moved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\mapua\retiled\invalid
# Checked TIFF files for dimensions in C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\mapua\retiled. Invalid files moved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\mapua\retiled\invalid
# Filtered TIFF files saved in C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\motueka\retiled. Invalid files moved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\motueka\retiled\invalid
# Checked TIFF files for dimensions in C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\motueka\retiled. Invalid files moved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\motueka\retiled\invalid
# Filtered TIFF files saved in C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\nelson\retiled. Invalid files moved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\nelson\retiled\invalid
# Checked TIFF files for dimensions in C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\nelson\retiled. Invalid files moved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\nelson\retiled\invalid
# Filtered TIFF files saved in C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\oamaru\retiled. Invalid files moved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\oamaru\retiled\invalid
# Checked TIFF files for dimensions in C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\oamaru\retiled. Invalid files moved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\oamaru\retiled\invalid
# Filtered TIFF files saved in C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\timaru\retiled. Invalid files moved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\timaru\retiled\invalid
# Checked TIFF files for dimensions in C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\timaru\retiled. Invalid files moved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\timaru\retiled\invalid
# Filtered TIFF files saved in C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\waikouaiti\retiled. Invalid files moved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\waikouaiti\retiled\invalid
# Checked TIFF files for dimensions in C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\waikouaiti\retiled. Invalid files moved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\waikouaiti\retiled\invalid
# Filtered TIFF files saved in C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\waituku\retiled. Invalid files moved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\waituku\retiled\invalid
# Checked TIFF files for dimensions in C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\waituku\retiled. Invalid files moved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\0.3m Aerial Imagery\waituku\retiled\invalid
# Processing complete.

# %%
total_valid_tifs = 0

for region_name in os.listdir(aerial_imagery_base_dir):
    region_dir = os.path.join(aerial_imagery_base_dir, region_name)
    if os.path.isdir(region_dir):
        retile_output_dir = os.path.join(region_dir, 'retiled')
        if os.path.exists(retile_output_dir):
            valid_tifs = glob.glob(os.path.join(retile_output_dir, '*.tif'))
            total_valid_tifs += len(valid_tifs)

print(f"Total number of valid TIFF files: {total_valid_tifs}")
# Out:
# Total number of valid TIFF files: 4502

# %% [markdown]
# ### Labelling data (Christchurch and Dunedin)
# Labelling coastline for Christchurch and Dunedin

# %%
labelled_areas_shapefile = os.path.join(input_dir, 'training', 'labelled areas.shp')
output_built_up_coastline_shapefile = os.path.join(input_dir, 'training', 'built_up_coastline.shp')

labelled_areas = gpd.read_file(labelled_areas_shapefile)
# Find the intersection of the intersecting coastline with the labelled areas
built_up_coastline = gpd.overlay(intersecting_coastlines, labelled_areas, how='intersection')

# Save the resulting segments to a new shapefile
built_up_coastline.to_file(output_built_up_coastline_shapefile)

print(f"Built-up coastline shapefile created at {output_built_up_coastline_shapefile}")
# Out:
# Built-up coastline shapefile created at C:\Users\owyn\Documents\SURV509\coastal classification\inputs\training\built_up_coastline.shp

# %% [markdown]
# ### Creating the label dataset

# %%
# List of regions to process
regions_to_process = ['christchurch', 'dunedin']

# Initialize list to store TIFF file names and their labels
tif_labels = []

# Iterate through specified regions
for region_name in regions_to_process:
    region_dir = os.path.join(aerial_imagery_base_dir, region_name, 'retiled')
    if os.path.isdir(region_dir):
        valid_tif_files = glob.glob(os.path.join(region_dir, '*.tif'))
        
        for tif_file in valid_tif_files:
            with rasterio.open(tif_file) as src:
                bounds = src.bounds
                geom = box(*bounds)
                intersects_built_up = built_up_coastline.intersects(geom).any()
                label = 1 if intersects_built_up else 0
                tif_labels.append((tif_file, label))

# Save the labels to a CSV file
tif_labels_df = pd.DataFrame(tif_labels, columns=['tif_file', 'label'])
output_csv = os.path.join(input_dir, 'training', 'tif_labels.csv')
tif_labels_df.to_csv(output_csv, index=False)

# Summary
total_observations = len(tif_labels)
total_ones = sum(label for _, label in tif_labels)
total_zeros = total_observations - total_ones

print(f"Total number of observations: {total_observations}")
print(f"Number of 1s: {total_ones}")
print(f"Number of 0s: {total_zeros}")
print(f"Labels saved to {output_csv}")
# Out:
# Total number of observations: 2482
# Number of 1s: 1075
# Number of 0s: 1407
# Labels saved to C:\Users\owyn\Documents\SURV509\coastal classification\inputs\training\tif_labels.csv

# %%
tif_labels
# Out:
# [('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_039_048.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_039_049.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_040_049.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_041_049.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_042_049.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_043_049.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_043_050.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_044_050.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_045_050.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_046_050.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_047_050.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_048_050.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_048_051.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_049_051.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_050_051.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_051_051.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_052_051.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_053_051.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_053_052.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_054_052.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_055_052.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_056_052.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_057_052.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_057_053.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_058_053.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_059_053.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_060_053.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_061_053.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_061_054.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_062_054.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_063_054.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_064_054.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_065_054.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_065_055.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_066_055.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_067_055.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_068_055.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_068_056.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_069_056.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_070_056.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_071_056.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_072_056.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_072_057.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_073_057.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_074_057.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_075_057.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_076_057.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_076_058.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_077_058.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_078_058.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_079_058.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_079_059.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_080_059.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_081_059.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_082_059.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_083_059.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_084_059.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_084_060.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_085_060.tif',
#   1),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_086_060.tif',
#   1),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_087_060.tif',
#   1),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_088_060.tif',
#   1),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_088_061.tif',
#   1),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_089_061.tif',
#   1),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_090_061.tif',
#   1),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_091_061.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_091_062.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_092_062.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_093_062.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_094_062.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_095_062.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_095_063.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_096_063.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_097_063.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_098_063.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_098_064.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_099_064.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_100_064.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_101_064.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_102_064.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_102_065.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_103_065.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_104_065.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_105_065.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_105_066.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_106_066.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_107_066.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_108_066.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_109_066.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_109_067.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_110_067.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_111_067.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_112_067.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_112_068.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_113_068.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_114_068.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_115_068.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_115_069.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_116_069.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_117_069.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_118_069.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_119_069.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_119_070.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_120_055.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_120_056.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_120_057.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_120_070.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_121_054.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_121_055.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_121_057.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_121_058.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_121_070.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_122_052.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_122_053.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_122_054.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_122_058.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_122_059.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_122_070.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_122_071.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_123_052.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_123_053.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_123_059.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_123_060.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_123_071.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_124_053.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_124_060.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_124_061.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_124_071.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_125_053.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_125_061.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_125_071.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_125_072.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_126_051.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_126_052.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_126_053.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_126_060.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_126_061.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_126_072.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_127_051.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_127_059.tif',
#   1),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_127_060.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_127_072.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_128_050.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_128_051.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_128_059.tif',
#   1),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_128_060.tif',
#   1),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_128_072.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_128_073.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_129_050.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_129_060.tif',
#   1),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_129_073.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_130_049.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_130_050.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_130_060.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_130_073.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_131_049.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_131_060.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_131_073.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_131_074.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_132_049.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_132_060.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_132_061.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_132_074.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_133_049.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_133_061.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_133_074.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_134_049.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_134_061.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_134_062.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_134_074.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_134_075.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_135_049.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_135_062.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_135_063.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_135_075.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_136_049.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_136_063.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_136_075.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_137_049.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_137_063.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_137_064.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_137_075.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_137_076.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_138_049.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_138_064.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_138_076.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_139_049.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_139_064.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_139_065.tif',
#   1),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_139_066.tif',
#   1),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_139_067.tif',
#   1),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_139_076.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_140_049.tif',
#   0),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105_140_067.tif',
#   1),
#  ('C:\\Users\\owyn\\Documents\\SURV509\\coastal classification\\inputs\\0.3m Aerial Imagery\\christchurch\\retiled\\BX24_5000_0105